# %% [markdown]
# # Team ID : PNT2022TMID31242

# %% [markdown]
# # Importing The Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %% [markdown]
# # Reading The Dataset

# %%
df = pd.read_csv("G:\Machine Learning Based Vehicle Performance Analyzer\car performance.csv")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Handling Missing Values

# %%
df.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# car name        False
# dtype: bool

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(df,diag_kind='kde')
plt.show()

# %% [markdown]
# HEATMAP

# %%
sns.heatmap(df.corr(),annot=True,linecolor ='black', linewidths = 1)
fig=plt.gcf()
fig.set_size_inches(5,5)

# %% [markdown]
# SEPERATING THE DATA

# %%
x=df[['cylinders','displacement','horsepower','weight','model year','origin']].values #INDEPENDENT VARIABLE
x
# Out:
# array([[8.000e+00, 3.070e+02, 1.300e+02, 3.504e+03, 7.000e+01, 1.000e+00],
#        [8.000e+00, 3.500e+02, 1.650e+02, 3.693e+03, 7.000e+01, 1.000e+00],
#        [8.000e+00, 3.180e+02, 1.500e+02, 3.436e+03, 7.000e+01, 1.000e+00],
#        ...,
#        [4.000e+00, 1.350e+02, 8.400e+01, 2.295e+03, 8.200e+01, 1.000e+00],
#        [4.000e+00, 1.200e+02, 7.900e+01, 2.625e+03, 8.200e+01, 1.000e+00],
#        [4.000e+00, 1.190e+02, 8.200e+01, 2.720e+03, 8.200e+01, 1.000e+00]])

# %%
y=df.iloc[:,0:1].values #DEPENDENT VARIABLE
y
# Out:
# array([[18. ],
#        [15. ],
#        [18. ],
#        [16. ],
#        [17. ],
#        [15. ],
#        [14. ],
#        [14. ],
#        [14. ],
#        [15. ],
#        [15. ],
#        [14. ],
#        [15. ],
#        [14. ],
#        [24. ],
#        [22. ],
#        [18. ],
#        [21. ],
#        [27. ],
#        [26. ],
#        [25. ],
#        [24. ],
#        [25. ],
#        [26. ],
#        [21. ],
#        [10. ],
#        [10. ],
#        [11. ],
#        [ 9. ],
#        [27. ],
#        [28. ],
#        [25. ],
#        [25. ],
#        [19. ],
#        [16. ],
#        [17. ],
#        [19. ],
#        [18. ],
#        [14. ],
#        [14. ],
#        [14. ],
#        [14. ],
#        [12. ],
#        [13. ],
#        [13. ],
#        [18. ],
#        [22. ],
#        [19. ],
#        [18. ],
#        [23. ],
#        [28. ],
#        [30. ],
#        [30. ],
#        [31. ],
#        [35. ],
#        [27. ],
#        [26. ],
#        [24. ],
# ...

# %% [markdown]
# # Splitting The Dataset Into Dependent And Independent Variable

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

# %% [markdown]
# Testing the Algorithms

# %% [markdown]
# 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=reg.predict(x_test)
y_pred1
# Out:
# array([[13.2162321 ],
#        [24.27285307],
#        [11.61772023],
#        [20.96641686],
#        [17.7358037 ],
#        [29.45346926],
#        [33.47436298],
#        [23.17018367],
#        [15.07249948],
#        [26.7641345 ],
#        [33.42858873],
#        [33.93286841],
#        [21.50648727],
#        [25.81726693],
#        [16.3148492 ],
#        [30.58507574],
#        [28.32755483],
#        [28.65569292],
#        [17.66424885],
#        [31.01488248],
#        [15.53264908],
#        [24.60373733],
#        [26.90214044],
#        [20.49512288],
#        [29.63732336],
#        [28.47040955],
#        [30.97812573],
#        [29.93363565],
#        [29.87143269],
#        [18.08117895],
#        [20.35120121],
#        [31.31836429],
#        [20.99073903],
#        [32.03819055],
#        [23.85718455],
#        [26.30866396],
#        [21.38233768],
#        [16.80219962],
#        [32.13262515],
#        [ 9.27349071]])

# %%
ax1 = sns.distplot(df['mpg'], hist=False, color="r", label="Actual Value")
sns.distplot(y_pred1, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for mpg')
plt.xlabel('mpg')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Calculating Metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.8519031381502012

# %%
mean_squared_error(y_test,y_pred1)
# Out:
# 10.236362530519433

# %%
np.sqrt(mean_squared_error(y_test,y_pred1))
# Out:
# 3.1994315949117325

# %% [markdown]
# 2.Using Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf= RandomForestRegressor(n_estimators=10,random_state=0,criterion='mae')
rf.fit(x_train,y_train)
# Out:
# C:\Users\Viswanathan R\AppData\Local\Temp\ipykernel_5160\4164760693.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:403: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warn(
# RandomForestRegressor(criterion='mae', n_estimators=10, random_state=0)

# %%
y_pred2=rf.predict(x_test)
y_pred2
# Out:
# array([14.25, 26.3 , 13.4 , 22.1 , 18.3 , 30.9 , 34.41, 24.85, 15.4 ,
#        25.29, 37.36, 38.61, 17.7 , 24.5 , 16.2 , 31.42, 29.07, 27.32,
#        16.82, 32.47, 16.05, 25.5 , 24.15, 20.2 , 32.4 , 25.58, 32.63,
#        31.97, 30.25, 16.37, 18.6 , 29.56, 17.97, 31.1 , 21.41, 24.15,
#        19.9 , 16.3 , 33.17, 11.9 ])

# %%
ax1 = sns.distplot(datas['mpg'], hist=False, color="r", label="Actual Value")
sns.distplot(y_pred2, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for mpg')
plt.xlabel('mpg')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Calculating Metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.921450931811811

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 5.429262500000002

# %%
np.sqrt(mean_squared_error(y_test,y_pred2))
# Out:
# 2.330077788401066

# %% [markdown]
# 3.Decesion Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(random_state = 0) 
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred3=dt.predict(x_test)
y_pred3
# Out:
# array([15. , 26.5, 13. , 19. , 16. , 31. , 31.8, 22. , 15. , 32.7, 29.8,
#        31.8, 18. , 26. , 15.5, 29. , 27. , 26.6, 16. , 44. , 16. , 23. ,
#        25. , 19. , 34.2, 32.7, 29.8, 36. , 32.4, 15. , 19. , 35. , 18. ,
#        32. , 19.1, 23. , 19.4, 16. , 29. , 12. ])

# %%
ax1 = sns.distplot(datas['mpg'], hist=False, color="r", label="Actual Value")
sns.distplot(y_pred3, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for mpg')
plt.xlabel('mpg')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Calculating Metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.8064037760758108

# %%
mean_squared_error(y_test,y_pred3)
# Out:
# 13.381250000000005

# %%
np.sqrt(mean_squared_error(y_test,y_pred3))
# Out:
# 3.6580390921913346

# %% [markdown]
# # Save our model by importing pickle file

# %%
import pickle
pickle.dump(datas,open('regression.pkl','wb'))
